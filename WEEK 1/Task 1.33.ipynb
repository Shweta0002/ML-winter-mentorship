# %%
import math 
def isPerfectSquare(x): 
 s = int(math.sqrt(x)) 
 return s*s == x 
def isFibonacci(n): 
 return isPerfectSquare(5*n*n + 4) or isPerfectSquare(5*n*n - 4) 
for i in range(1,100): 
 if (isFibonacci(i) == True): 
  print (i,"is a Fibonacci Number")
 else: 
  print (i,"is a not Fibonacci Number ")
# Out:
# 1 is a Fibonacci Number
# 2 is a Fibonacci Number
# 3 is a Fibonacci Number
# 4 is a not Fibonacci Number
# 5 is a Fibonacci Number
# 6 is a not Fibonacci Number
# 7 is a not Fibonacci Number
# 8 is a Fibonacci Number
# 9 is a not Fibonacci Number
# 10 is a not Fibonacci Number
# 11 is a not Fibonacci Number
# 12 is a not Fibonacci Number
# 13 is a Fibonacci Number
# 14 is a not Fibonacci Number
# 15 is a not Fibonacci Number
# 16 is a not Fibonacci Number
# 17 is a not Fibonacci Number
# 18 is a not Fibonacci Number
# 19 is a not Fibonacci Number
# 20 is a not Fibonacci Number
# 21 is a Fibonacci Number
# 22 is a not Fibonacci Number
# 23 is a not Fibonacci Number
# 24 is a not Fibonacci Number
# 25 is a not Fibonacci Number
# 26 is a not Fibonacci Number
# 27 is a not Fibonacci Number
# 28 is a not Fibonacci Number
# 29 is a not Fibonacci Number
# 30 is a not Fibonacci Number
# 31 is a not Fibonacci Number
# 32 is a not Fibonacci Number
# 33 is a not Fibonacci Number
# 34 is a Fibonacci Number
# 35 is a not Fibonacci Number
# 36 is a not Fibonacci Number
# 37 is a not Fibonacci Number
# 38 is a not Fibonacci Number
# 39 is a not Fibonacci Number
# 40 is a not Fibonacci Number
# 41 is a not Fibonacci Number
# 42 is a not Fibonacci Number
# 43 is a not Fibonacci Number
# 44 is a not Fibonacci Number
# 45 is a not Fibonacci Number
# 46 is a not Fibonacci Number
# 47 is a not Fibonacci Number
# 48 is a not Fibonacci Number
# 49 is a not Fibonacci Number
# 50 is a not Fibonacci Number
# 51 is a not Fibonacci Number
# 52 is a not Fibonacci Number
# 53 is a not Fibonacci Number
# 54 is a not Fibonacci Number
# 55 is a Fibonacci Number
# 56 is a not Fibonacci Number
# 57 is a not Fibonacci Number
# 58 is a not Fibonacci Number
# 59 is a not Fibonacci Number
# 60 is a not Fibonacci Number
# 61 is a not Fibonacci Number
# 62 is a not Fibonacci Number
# 63 is a not Fibonacci Number
# 64 is a not Fibonacci Number
# 65 is a not Fibonacci Number
# 66 is a not Fibonacci Number
# 67 is a not Fibonacci Number
# 68 is a not Fibonacci Number
# 69 is a not Fibonacci Number
# 70 is a not Fibonacci Number
# 71 is a not Fibonacci Number
# 72 is a not Fibonacci Number
# 73 is a not Fibonacci Number
# 74 is a not Fibonacci Number
# 75 is a not Fibonacci Number
# 76 is a not Fibonacci Number
# 77 is a not Fibonacci Number
# 78 is a not Fibonacci Number
# 79 is a not Fibonacci Number
# 80 is a not Fibonacci Number
# 81 is a not Fibonacci Number
# 82 is a not Fibonacci Number
# 83 is a not Fibonacci Number
# 84 is a not Fibonacci Number
# 85 is a not Fibonacci Number
# 86 is a not Fibonacci Number
# 87 is a not Fibonacci Number
# 88 is a not Fibonacci Number
# 89 is a Fibonacci Number
# 90 is a not Fibonacci Number
# 91 is a not Fibonacci Number
# 92 is a not Fibonacci Number
# 93 is a not Fibonacci Number
# 94 is a not Fibonacci Number
# 95 is a not Fibonacci Number
# 96 is a not Fibonacci Number
# 97 is a not Fibonacci Number
# 98 is a not Fibonacci Number
# 99 is a not Fibonacci Number
